# %%
# !pip install openpyxl

# %%
import pandas as pd
# Out:
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
data = pd.read_excel("datasets/01-attendantsheet-sample.xlsx")

# %%
data.head(20)
# Out:
#        Unnamed: 0            Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0             NaN                   NaN        NaN        NaN
# 1             NaN                   NaN        NaN        NaN
# 2             NaN                   NaN        NaN        NaN
# 3             NaN                   NaN        NaN        NaN
# 4             NaN                   NaN        NaN        NaN
# 5             NaN                   NaN        NaN        NaN
# 6   Date: (MM/DD)                   NaN        NaN        NaN
# 7             No.                  Name        Sex     Course
# 8               1            Chan Panha          M         AW
# 9               2  Chum Ratanakchentria          F         AW
# 10              3           Eang Montra          F         AW
# 11              4          Eung Laimeng          M         AW
# 12              5      Soeun Kongsovann          M         AW
# 13              6           Kril Darith          M         AW
# ...

# %%
data.iloc[6:22, :34]
# Out:
#        Unnamed: 0            Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 6   Date: (MM/DD)                   NaN        NaN        NaN
# 7             No.                  Name        Sex     Course
# 8               1            Chan Panha          M         AW
# 9               2  Chum Ratanakchentria          F         AW
# 10              3           Eang Montra          F         AW
# 11              4          Eung Laimeng          M         AW
# 12              5      Soeun Kongsovann          M         AW
# 13              6           Kril Darith          M         AW
# 14              7  Mao Kolbotr Pisssoth          M         AW
# 15              8            Ny Clinton          M         AW
# 16              9  Phok Keomonnyratanak          M       USB1
# 17             10      Rith Sokha Neadh          M       USB2
# 18             11              Sat Dona          M       USB3
# 19             12         SOPHEAP Neary          M       USB4
# ...
